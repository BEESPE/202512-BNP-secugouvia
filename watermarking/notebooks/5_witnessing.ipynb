# %%
import os
import sys; sys.path.insert(0, "..")

from dotenv import load_dotenv
import matplotlib.pyplot as plt
import numpy as np
import pickle
from skimage import filters
import tensorflow as tf

from src.watermarking.content.noise.saltpepper import SaltpepperNoiseWatermarker
from src.watermarking.metadata import AuthorWatermarker
from src.watermarking.output import DecimalTurner, MagicModel

# %%
load_dotenv()
DATASET_FOLDER = os.getenv("DATASET_FOLDER")
MARKER_FOLDER = os.getenv("MARKER_FOLDER")
SAVE_FOLDER = os.path.join(os.getcwd(), os.pardir, "saved_objects")

# %% [markdown]
# Charger les objets sauvegardés nécessaires avec pickle.

# %%
# ✏️ Votre code ici

# %% [markdown]
# ### <font color="purple"> Decimal Turner.</font>

# %% [markdown]
# Essayer de trouver quel modèle applique un DecimalTurner. Bonus : réaliser ceci en réfléchissant à utiliser le moins d'objets internes possibles (par exemple type(model)). Le mieux étant de pouvoir réaliser le witness avec un appel extérieur au modèle.

# %%
# ✏️ Votre code ici

# %% [markdown]
# Bonus : implémenter une attaque du DecimalTurner, en connaissance de son principe.

# %%
# ✏️ Votre code ici

# %% [markdown]
# Mais attention à la dégradation des performances !

# %% [markdown]
# ### <font color="purple"> Saltpepper Noise.</font>

# %% [markdown]
# Mêmes questions pour le saltpepper watermarking.

# %%
# ✏️ Votre code ici

# %% [markdown]
# Bonus ++ : créer une attaque générique par fine tuning.

# %%
# ✏️ Votre code ici

# %% [markdown]
# Bonus +++ : étudier l'impact sur les performances

# %%
# ✏️ Votre code ici
