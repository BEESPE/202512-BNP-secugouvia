# %%
import sys; sys.path.append("..")
import os
from pathlib import Path
import pickle as pkl

from dotenv import load_dotenv
from matplotlib.image import imread
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input

from src.watermarking.content.noise.saltpepper import generate_saltpepper_masks
from src.constants import IMG_SQUARE_SIDE

# %%
load_dotenv()
IMG_FOLDER = Path(os.getenv("DATASET_FOLDER"))

# %% [markdown]
# Générer un watermark salt and pepper.

# %%
black_mask, white_mask = ... # ✏️ à compléter

# %%
print(white_mask.shape)
print(white_mask.sum())

# %% [markdown]
# Appliquer le watermarking sur une image et visualiser son effet.

# %%
path_to_test_img = ... # ✏️ à compléter

# %%
saltpepper_image = img_to_array(
    load_img(
        ...  # ✏️ à compléter,
        target_size=...,  # ✏️ à compléter
    )
).astype(int)

# %%
plt.figure()
# ✏️ à compléter
plt.show()

# %%
saltpepper_image = ... # ✏️ à compléter

# %%
plt.figure()
# ✏️ à compléter
plt.show()

# %% [markdown]
# Vérifier si ce watermark est robuste à la fonction de preprocessing utilisée.

# %%
# ✏️ à compléter

# %% [markdown]
# Sauvegarder les deux masques dans le dossier markers au format pickle (vous pouvez sauvegarder plusieurs paires correspondant à des valeurs de p différentes).

# %%
# ✏️ à compléter
